# %%
# Import pandas dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import r2_score
import seaborn as sns

# %%
# Load cleaned byarea_df
c_byarea_df = pd.read_csv('../Resources/cleaned_byarea_df.csv', ',')
c_byarea_df.head()
# Out:
# C:\Users\yingk\anaconda3\envs\mlenv\lib\site-packages\IPython\core\interactiveshell.py:3457: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only
#   exec(code_obj, self.user_global_ns, self.user_ns)
#       AREA  AGE_ADJUSTED_CI_LOWER  AGE_ADJUSTED_CI_UPPER  AGE_ADJUSTED_RATE  \
# 0  Alabama                  359.7                  374.7              367.2
# 1  Alabama                  160.6                  170.5              165.5
# 2  Alabama                  362.1                  377.1              369.5
# 3  Alabama                  160.8                  170.6              165.7
# 4  Alabama                  377.7                  392.9              385.2
#
#   EVENT_TYPE  POPULATION       RACE     SEX                       SITE  YEAR  \
# 0  Incidence     2293259  All Races  Female  All Cancer Sites Combined  1999
# 1  Mortality     2293259  All Races  Female  All Cancer Sites Combined  1999
# 2  Incidence     2302835  All Races  Female  All Cancer Sites Combined  2000
# 3  Mortality     2302835  All Races  Female  All Cancer Sites Combined  2000
# 4  Incidence     2309496  All Races  Female  All Cancer Sites Combined  2001
#
#    CRUDE_CI_LOWER  CRUDE_CI_UPPER  CRUDE_RATE
# 0           397.3           413.8       405.5
# 1           184.8           196.1       190.4
# 2           403.2           419.8       411.4
# 3           186.5           197.9       192.2
# 4           423.3           440.3       431.7

# %%
# check c_byarea_df columns
c_byarea_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 949308 entries, 0 to 949307
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   AREA                   949308 non-null  object
#  1   AGE_ADJUSTED_CI_LOWER  949308 non-null  float64
#  2   AGE_ADJUSTED_CI_UPPER  949308 non-null  float64
#  3   AGE_ADJUSTED_RATE      949308 non-null  float64
#  4   EVENT_TYPE             949308 non-null  object
#  5   POPULATION             949308 non-null  int64
#  6   RACE                   949308 non-null  object
#  7   SEX                    949308 non-null  object
#  8   SITE                   949308 non-null  object
#  9   YEAR                   949308 non-null  int64
#  10  CRUDE_CI_LOWER         949308 non-null  float64
#  11  CRUDE_CI_UPPER         949308 non-null  float64
#  12  CRUDE_RATE             949308 non-null  float64
# dtypes: float64(6), int64(2), object(5)
# memory usage: 94.2+ MB

# %%
# load smoking_rate.csv file
smoking_df = pd.read_csv('../Resources/smoking_rate.csv')
smoking_df.head(3)
# Out:
#      State  2011  2012  2013  2014  2015  2016  2017  2018  2019  2020
# 0  Alabama  24.3  23.8  21.5  21.1  21.4  21.5  20.9  19.2  20.2  17.2
# 1   Alaska  22.9  20.5  22.6  19.9  19.1  19.0  21.0  19.1  17.4  17.1
# 2  Arizona  19.3  17.1  16.3  16.5  14.0  14.7  15.6  14.0  14.9  13.1

# %%
# load obesity_rate.csv file
obesity_df = pd.read_csv('../Resources/obesity_rate.csv')
obesity_df.head(3)
# Out:
#      State  2010  2011  2012  2013  2014  2015  2016  2017  2018  2019
# 0  Alabama  33.0  32.0  33.0  32.4  33.5  35.6  35.7  36.3  36.2  36.1
# 1   Alaska  25.2  27.4  25.7  28.4  29.7  29.8  31.4  34.2  29.5  30.5
# 2  Arizona  25.2  25.1  26.0  26.8  28.9  28.4  29.0  29.5  30.0  31.4

# %%
# load per_capita_income file
income_df = pd.read_csv('../Resources/cleaned_per_capita_income.csv')
income_df.head(3)
# Out:
#          GeoName   1999   2000   2001   2002   2003   2004   2005   2006  \
# 0  United States  28693  30672  31617  31839  32717  34280  35868  38120
# 1        Alabama  23333  24306  25057  25648  26673  28434  29949  31474
# 2         Alaska  29951  32044  33626  34756  35996  37016  39075  41157
#
#     2007  ...   2010   2011   2012   2013   2014   2015   2016   2017   2018  \
# 0  39883  ...  40683  42747  44548  44798  46887  48725  49613  51550  53786
# 1  32739  ...  33946  35010  35824  36014  37055  38531  39014  40223  41539
# 2  43906  ...  49652  52569  53708  52812  55867  57575  56278  57189  59618
#
#     2019
# 0  56250
# 1  43288
# 2  61316
#
# [3 rows x 22 columns]

# %% [markdown]
# ## prepare smoking data

# %%
# reshape smoking_df to long form to merge with cancer data
# how to: https://towardsdatascience.com/how-to-reshape-a-pandas-dataframe-98b42c428a8

# first need to rename each column in order to use the wide_to_long()
smoking_df.rename(columns={'2011':'smoking_2011',
                           '2012':'smoking_2012',
                           '2013':'smoking_2013',
                           '2014':'smoking_2014',
                           '2015':'smoking_2015',
                           '2016':'smoking_2016',
                           '2017':'smoking_2017',
                           '2018':'smoking_2018',
                           '2019':'smoking_2019',
                           '2020':'smoking_2020'}, inplace=True)

# %%
smoking_df.head()
# Out:
#         State  smoking_2011  smoking_2012  smoking_2013  smoking_2014  \
# 0     Alabama          24.3          23.8          21.5          21.1
# 1      Alaska          22.9          20.5          22.6          19.9
# 2     Arizona          19.3          17.1          16.3          16.5
# 3    Arkansas          27.0          25.0          25.9          24.7
# 4  California          13.7          12.6          12.5          12.9
#
#    smoking_2015  smoking_2016  smoking_2017  smoking_2018  smoking_2019  \
# 0          21.4          21.5          20.9          19.2          20.2
# 1          19.1          19.0          21.0          19.1          17.4
# 2          14.0          14.7          15.6          14.0          14.9
# 3          24.9          23.6          22.3          22.7          20.2
# 4          11.7          11.0          11.3          11.2          10.0
#
#    smoking_2020
# 0          17.2
# 1          17.1
# 2          13.1
# 3          21.1
# 4           8.8

# %%
# convert smoking_df to long format
smoking_long_df = pd.wide_to_long(smoking_df, 
                              stubnames=['smoking'],
                              i='State',
                              j='YEAR',
                              sep="_",
                              suffix='\w+')
smoking_long_df
# Out:
#                     smoking
# State         YEAR
# Alabama       2011     24.3
# Alaska        2011     22.9
# Arizona       2011     19.3
# Arkansas      2011     27.0
# California    2011     13.7
# ...                     ...
# West Virginia 2020     22.0
# Wisconsin     2020     13.3
# Wyoming       2020     16.4
# Guam          2020     20.0
# Puerto Rico   2020      9.9
#
# [530 rows x 1 columns]

# %%
# Adding back index for ease of merging later
smoking_long_df = smoking_long_df.reset_index()
smoking_long_df
# Out:
#              State  YEAR  smoking
# 0          Alabama  2011     24.3
# 1           Alaska  2011     22.9
# 2          Arizona  2011     19.3
# 3         Arkansas  2011     27.0
# 4       California  2011     13.7
# ..             ...   ...      ...
# 525  West Virginia  2020     22.0
# 526      Wisconsin  2020     13.3
# 527        Wyoming  2020     16.4
# 528           Guam  2020     20.0
# 529    Puerto Rico  2020      9.9
#
# [530 rows x 3 columns]

# %% [markdown]
# ## prepare obesity data

# %%
# reshape obesity_df to long form to merge with cancer data
obesity_df.rename(columns={'2010':'obesity_2010',
                           '2011':'obesity_2011',
                           '2012':'obesity_2012',
                           '2013':'obesity_2013',
                           '2014':'obesity_2014',
                           '2015':'obesity_2015',
                           '2016':'obesity_2016',
                           '2017':'obesity_2017',
                           '2018':'obesity_2018',
                           '2019':'obesity_2019'}, inplace=True)

# %%
# convert obesity_df to long format
obesity_long_df = pd.wide_to_long(obesity_df, 
                              stubnames=['obesity'],
                              i='State',
                              j='YEAR',
                              sep="_",
                              suffix='\w+')
obesity_long_df
# Out:
#                     obesity
# State         YEAR
# Alabama       2010     33.0
# Alaska        2010     25.2
# Arizona       2010     25.2
# Arkansas      2010     30.9
# California    2010     24.7
# ...                     ...
# West Virginia 2019     39.7
# Wisconsin     2019     34.2
# Wyoming       2019     29.7
# Guam          2019     33.6
# Puerto Rico   2019     32.5
#
# [530 rows x 1 columns]

# %% [markdown]
# ## prepare INCOME data

# %%
# first need to rename each column in order to use the wide_to_long()
income_df.rename(columns={'1999':'INCOME_1999',
                       '2000':'INCOME_2000',
                       '2001':'INCOME_2001',
                       '2002':'INCOME_2002',
                       '2003':'INCOME_2003',
                       '2004':'INCOME_2004',
                       '2005':'INCOME_2005',
                       '2006':'INCOME_2006',
                       '2007':'INCOME_2007',
                       '2008':'INCOME_2008',
                       '2009':'INCOME_2009',
                       '2010':'INCOME_2010',
                       '2011':'INCOME_2011',
                       '2012':'INCOME_2012',
                       '2013':'INCOME_2013',
                       '2014':'INCOME_2014',
                       '2015':'INCOME_2015',
                       '2016':'INCOME_2016',
                       '2017':'INCOME_2017',
                       '2018':'INCOME_2018',
                       '2019':'INCOME_2019',}, inplace=True)

# %%
# convert income_df to long format
income_long_df = pd.wide_to_long(income_df, 
                              stubnames=['INCOME'],
                              i='GeoName',
                              j='YEAR',
                              sep="_",
                              suffix='\w+')
income_long_df
# Out:
#                     INCOME
# GeoName       YEAR
# United States 1999   28693
# Alabama       1999   23333
# Alaska        1999   29951
# Arizona       1999   24960
# Arkansas      1999   21871
# ...                    ...
# Virginia      2019   59073
# Washington    2019   64189
# West Virginia 2019   42951
# Wisconsin     2019   52893
# Wyoming       2019   64117
#
# [1092 rows x 1 columns]

# %% [markdown]
# ## prepare cancer data

# %%
# filter for rows for state lung cancer mortality rate by all sex and race 
cancer_df = c_byarea_df.loc[(c_byarea_df['EVENT_TYPE']=='Mortality') &
                              (c_byarea_df['SEX']=='Male and Female') &
                              (c_byarea_df['RACE']=='All Races') &
                              (c_byarea_df['SITE']=='Lung and Bronchus') &
                              (c_byarea_df['YEAR']!= 20152019)
                              ]
cancer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1071 entries, 2575 to 933049
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   AREA                   1071 non-null   object
#  1   AGE_ADJUSTED_CI_LOWER  1071 non-null   float64
#  2   AGE_ADJUSTED_CI_UPPER  1071 non-null   float64
#  3   AGE_ADJUSTED_RATE      1071 non-null   float64
#  4   EVENT_TYPE             1071 non-null   object
#  5   POPULATION             1071 non-null   int64
#  6   RACE                   1071 non-null   object
#  7   SEX                    1071 non-null   object
#  8   SITE                   1071 non-null   object
#  9   YEAR                   1071 non-null   int64
#  10  CRUDE_CI_LOWER         1071 non-null   float64
#  11  CRUDE_CI_UPPER         1071 non-null   float64
#  12  CRUDE_RATE             1071 non-null   float64
# dtypes: float64(6), int64(2), object(5)
# memory usage: 117.1+ KB

# %%
cancer_df.head(3)
# Out:
#          AREA  AGE_ADJUSTED_CI_LOWER  AGE_ADJUSTED_CI_UPPER  \
# 2575  Alabama                   60.2                   64.8
# 2577  Alabama                   61.9                   66.6
# 2579  Alabama                   60.3                   64.9
#
#       AGE_ADJUSTED_RATE EVENT_TYPE  POPULATION       RACE              SEX  \
# 2575               62.5  Mortality     4430141  All Races  Male and Female
# 2577               64.2  Mortality     4452173  All Races  Male and Female
# 2579               62.6  Mortality     4467634  All Races  Male and Female
#
#                    SITE  YEAR  CRUDE_CI_LOWER  CRUDE_CI_UPPER  CRUDE_RATE
# 2575  Lung and Bronchus  1999            62.0            66.8        64.4
# 2577  Lung and Bronchus  2000            64.2            69.0        66.6
# 2579  Lung and Bronchus  2001            62.8            67.6        65.2

# %%
# Pick out just the columns needed for our multiple regression analysis
# CRUDE_RATE as the independent variable
cancer_mr_df = cancer_df[['AREA', 'YEAR', 'AGE_ADJUSTED_RATE']]
cancer_mr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1071 entries, 2575 to 933049
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   AREA               1071 non-null   object
#  1   YEAR               1071 non-null   int64
#  2   AGE_ADJUSTED_RATE  1071 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 33.5+ KB

# %%
cancer_mr_df
# Out:
#            AREA  YEAR  AGE_ADJUSTED_RATE
# 2575    Alabama  1999               62.5
# 2577    Alabama  2000               64.2
# 2579    Alabama  2001               62.6
# 2581    Alabama  2002               63.5
# 2583    Alabama  2003               65.0
# ...         ...   ...                ...
# 933039  Wyoming  2015               32.0
# 933043  Wyoming  2016               30.3
# 933045  Wyoming  2017               30.5
# 933047  Wyoming  2018               29.5
# 933049  Wyoming  2019               29.4
#
# [1071 rows x 3 columns]

# %% [markdown]
# ## prepare Multiple Regression data

# %%
# merge the cancer df and smoking df
mr_df = pd.merge(smoking_long_df, cancer_mr_df, how='left', left_on=['State', 'YEAR'], right_on=['AREA', 'YEAR'])
mr_df.head(3)
# Out:
#      State  YEAR  smoking     AREA  AGE_ADJUSTED_RATE
# 0  Alabama  2011     24.3  Alabama               56.9
# 1   Alaska  2011     22.9   Alaska               50.4
# 2  Arizona  2011     19.3  Arizona               36.7

# %%
mr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 530 entries, 0 to 529
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   State              530 non-null    object
#  1   YEAR               530 non-null    int64
#  2   smoking            529 non-null    float64
#  3   AREA               459 non-null    object
#  4   AGE_ADJUSTED_RATE  459 non-null    float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 24.8+ KB

# %%
# merge obesity to mr_df
mr_df = pd.merge(obesity_long_df, mr_df, how='left', left_on=['State', 'YEAR'], right_on=['AREA', 'YEAR'])
mr_df
# Out:
#      obesity  YEAR          State  smoking           AREA  AGE_ADJUSTED_RATE
# 0       33.0  2010            NaN      NaN            NaN                NaN
# 1       25.2  2010            NaN      NaN            NaN                NaN
# 2       25.2  2010            NaN      NaN            NaN                NaN
# 3       30.9  2010            NaN      NaN            NaN                NaN
# 4       24.7  2010            NaN      NaN            NaN                NaN
# ..       ...   ...            ...      ...            ...                ...
# 525     39.7  2019  West Virginia     23.8  West Virginia               48.3
# 526     34.2  2019      Wisconsin     15.4      Wisconsin               34.6
# 527     29.7  2019        Wyoming     18.4        Wyoming               29.4
# 528     33.6  2019            NaN      NaN            NaN                NaN
# 529     32.5  2019            NaN      NaN            NaN                NaN
#
# [530 rows x 6 columns]

# %%
# merge income to mr_df
mr_df = pd.merge(income_long_df, mr_df, how='left', left_on=['GeoName', 'YEAR'], right_on=['AREA', 'YEAR'])
mr_df
# Out:
#       INCOME  YEAR  obesity          State  smoking           AREA  \
# 0      28693  1999      NaN            NaN      NaN            NaN
# 1      23333  1999      NaN            NaN      NaN            NaN
# 2      29951  1999      NaN            NaN      NaN            NaN
# 3      24960  1999      NaN            NaN      NaN            NaN
# 4      21871  1999      NaN            NaN      NaN            NaN
# ...      ...   ...      ...            ...      ...            ...
# 1087   59073  2019     31.9       Virginia     14.0       Virginia
# 1088   64189  2019     28.3     Washington     12.6     Washington
# 1089   42951  2019     39.7  West Virginia     23.8  West Virginia
# 1090   52893  2019     34.2      Wisconsin     15.4      Wisconsin
# 1091   64117  2019     29.7        Wyoming     18.4        Wyoming
#
#       AGE_ADJUSTED_RATE
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# ...                 ...
# 1087               33.8
# 1088               31.1
# 1089               48.3
# 1090               34.6
# 1091               29.4
#
# [1092 rows x 7 columns]

# %%
mr_df = mr_df.dropna()
mr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 458 entries, 625 to 1091
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   INCOME             458 non-null    int64
#  1   YEAR               458 non-null    int64
#  2   obesity            458 non-null    float64
#  3   State              458 non-null    object
#  4   smoking            458 non-null    float64
#  5   AREA               458 non-null    object
#  6   AGE_ADJUSTED_RATE  458 non-null    float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 28.6+ KB

# %%
mr_df
# Out:
#       INCOME  YEAR  obesity          State  smoking           AREA  \
# 625    35010  2011     32.0        Alabama     24.3        Alabama
# 626    52569  2011     27.4         Alaska     22.9         Alaska
# 627    35321  2011     25.1        Arizona     19.3        Arizona
# 628    34279  2011     30.9       Arkansas     27.0       Arkansas
# 629    45557  2011     23.8     California     13.7     California
# ...      ...   ...      ...            ...      ...            ...
# 1087   59073  2019     31.9       Virginia     14.0       Virginia
# 1088   64189  2019     28.3     Washington     12.6     Washington
# 1089   42951  2019     39.7  West Virginia     23.8  West Virginia
# 1090   52893  2019     34.2      Wisconsin     15.4      Wisconsin
# 1091   64117  2019     29.7        Wyoming     18.4        Wyoming
#
#       AGE_ADJUSTED_RATE
# 625                56.9
# 626                50.4
# 627                36.7
# 628                61.2
# 629                34.9
# ...                 ...
# 1087               33.8
# 1088               31.1
# 1089               48.3
# 1090               34.6
# 1091               29.4
#
# [458 rows x 7 columns]

# %%
mr_df.drop(columns = ['AREA','YEAR','State'], inplace=True)
mr_df
# Out:
# C:\Users\yingk\anaconda3\envs\mlenv\lib\site-packages\pandas\core\frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#       INCOME  obesity  smoking  AGE_ADJUSTED_RATE
# 625    35010     32.0     24.3               56.9
# 626    52569     27.4     22.9               50.4
# 627    35321     25.1     19.3               36.7
# 628    34279     30.9     27.0               61.2
# 629    45557     23.8     13.7               34.9
# ...      ...      ...      ...                ...
# 1087   59073     31.9     14.0               33.8
# 1088   64189     28.3     12.6               31.1
# 1089   42951     39.7     23.8               48.3
# 1090   52893     34.2     15.4               34.6
# 1091   64117     29.7     18.4               29.4
#
# [458 rows x 4 columns]

# %%
corr = mr_df.corr()
corr.head()
# Out:
#                      INCOME   obesity   smoking  AGE_ADJUSTED_RATE
# INCOME             1.000000 -0.339503 -0.556185          -0.520832
# obesity           -0.339503  1.000000  0.492728           0.443556
# smoking           -0.556185  0.492728  1.000000           0.855878
# AGE_ADJUSTED_RATE -0.520832  0.443556  0.855878           1.000000

# %%
sns.heatmap(corr)
import seaborn as sns
sns.set(rc={'figure.figsize':(16,21)})

# %%
X = mr_df[['INCOME', 'obesity','smoking']]
y = mr_df['AGE_ADJUSTED_RATE']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
model = LinearRegression()
model.fit (X_train, y_train)
# Out:
# LinearRegression()

# %%
coef = model.coef_
print(coef)
# Out:
# [-3.06331668e-05  1.80759258e-03  2.08535588e+00]

# %%
intercept = model.intercept_
print(intercept)
# Out:
# 4.680707037322961

# %%
pred_y = model.predict(X_train)
pred_y
# Out:
# array([57.76984707, 49.29435549, 36.90734024, 46.08739152, 30.96965777,
#        59.99109611, 57.13623476, 29.15007857, 40.36455572, 39.88631194,
#        36.09242242, 37.19125001, 37.85345648, 41.85065922, 50.27316679,
#        32.00883946, 43.47093863, 33.5249364 , 53.9543228 , 49.63038514,
#        48.84682863, 33.9214335 , 35.12983701, 31.06656816, 29.31426744,
#        45.02759659, 39.49662878, 45.14458812, 42.86369048, 48.95467161,
#        33.56386128, 35.97234349, 30.05600551, 47.6834439 , 49.91561913,
#        39.14272769, 39.62306111, 35.68377484, 29.06869233, 33.53666254,
#        42.07898207, 44.2496633 , 48.19134664, 36.52086415, 54.79412996,
#        46.04196008, 31.38592912, 40.53990427, 36.87944907, 28.94784482,
#        36.73584725, 39.18433182, 50.75635791, 42.46985421, 38.84836063,
#        37.22827149, 33.49283499, 58.89807923, 48.38526717, 39.15547983,
#        30.8164881 , 51.56828795, 27.45219787, 39.55323644, 48.40516562,
#        37.25383446, 22.10029748, 57.94551162, 39.58643254, 39.97661734,
#        26.19914397, 34.81718546, 40.8072308 , 43.50567953, 38.50148387,
#        39.38694422, 31.12887345, 38.45064553, 30.75991833, 39.85327681,
#        35.90322312, 60.59246691, 51.63908685, 43.63073975, 47.81227718,
#        37.54164541, 50.24328677, 39.13005611, 50.09005298, 38.16096849,
#        51.23274612, 42.23656026, 40.74709865, 37.46597708, 40.38028125,
#        44.59256835, 33.35586821, 42.06748486, 47.95523997, 36.59454505,
#        39.7966539 , 49.09474796, 37.94018216, 43.89145203, 49.21729741,
#        36.87836645, 55.20420461, 36.123943  , 37.60557888, 32.20345567,
#        37.74494113, 44.21061185, 43.45089356, 45.5441014 , 21.79881693,
#        42.84150599, 49.46395376, 62.65389126, 43.16907248, 44.65879608,
#        54.20716986, 37.33114602, 34.47012342, 39.652718  , 39.61134119,
#        43.80315949, 27.65229915, 45.91671075, 39.05904125, 38.95879437,
#        54.61607741, 37.53477541, 35.91194134, 40.79777707, 25.08498804,
#        46.08615024, 44.65427262, 44.06156284, 50.78561193, 52.07533036,
#        40.92650584, 41.07136068, 41.88416645, 35.40231735, 40.15412247,
#        41.97719367, 42.63722356, 33.17965811, 39.38925971, 30.53712736,
#        33.47524139, 42.78241775, 44.92528373, 28.61400656, 26.48924633,
#        35.00730467, 38.44520108, 33.30736351, 36.21026114, 44.31041846,
#        32.71369922, 47.26452623, 23.7859075 , 52.70756746, 40.06827178,
#        40.82905752, 52.47892365, 35.23672718, 34.51172373, 35.32932792,
#        36.77024007, 49.57926588, 32.07089992, 42.69982555, 40.17787322,
#        41.29384718, 49.49746411, 44.73508178, 35.31840713, 28.28466372,
#        43.29001172, 53.559973  , 37.74343753, 47.21490938, 40.95045414,
#        43.33038768, 34.83631613, 39.56918284, 55.87462652, 51.29178042,
#        58.22096548, 49.50679394, 35.71727845, 27.5077829 , 57.76070225,
#        25.72645671, 53.274425  , 49.6616396 , 45.5100558 , 53.06821329,
#        46.40816791, 51.32360637, 43.51250369, 32.69146685, 38.67754686,
#        42.79141838, 34.49202076, 31.89754813, 42.63525382, 23.59295022,
#        45.9601418 , 46.5737254 , 46.0115517 , 36.27909368, 53.47250317,
#        39.14771022, 37.10625518, 32.6616965 , 46.12597737, 39.86758436,
#        40.91058378, 33.73956663, 31.25431033, 35.07707744, 34.33507755,
#        45.04002103, 35.1738638 , 42.79054039, 35.64769649, 40.7507931 ,
#        40.30601293, 39.60564138, 52.81400808, 33.82746178, 45.89044484,
#        43.10096213, 35.86474086, 46.04655473, 31.91162645, 52.61705277,
#        42.10910574, 38.6606944 , 56.96358837, 55.06688529, 51.85190078,
#        33.18534624, 47.30528102, 32.30379744, 50.98227144, 42.75886753,
#        40.01704709, 34.66248118, 55.44408401, 35.76977696, 45.18479736,
#        28.70013996, 34.3826653 , 39.80843687, 35.23317845, 55.32061135,
#        21.9614977 , 47.40347832, 59.30398521, 36.73044645, 43.48676434,
#        34.64939269, 38.891491  , 49.96418557, 25.93219963, 57.6304344 ,
#        39.26780093, 50.87452981, 56.03856866, 46.58628308, 47.0523531 ,
#        39.03211608, 42.80116605, 48.89922673, 32.9812053 , 33.39563965,
#        50.55587725, 39.24088837, 44.11553072, 45.83171161, 34.45353292,
#        35.6302181 , 39.02558238, 46.95982854, 36.80356235, 40.85186618,
#        30.05680282, 50.98218861, 37.63372567, 43.58603493, 33.74037751,
#        37.70786957, 47.09810269, 41.8281578 , 35.41766462, 35.55943677,
#        55.7563435 , 27.9376225 , 51.13343801, 33.57252667, 47.31343225,
#        29.04103366, 44.4753819 , 41.04206906, 44.46083847, 63.3211257 ,
#        42.33669629, 40.05927807, 57.19093998, 40.99615129, 38.64480609,
#        44.82519699, 31.11464674, 44.76155647, 35.95232389, 40.70404684,
#        30.97297728, 36.8384844 , 34.11740935, 35.93313191, 36.83809178,
#        43.96893613, 42.41197044, 32.53714959, 62.46280185, 37.8554043 ,
#        52.03400365, 49.91260568, 40.36221358, 45.62173028, 41.14083399,
#        42.9739827 , 47.22012016, 36.89632889, 29.30544868, 38.14595329,
#        50.49425309, 33.73731115, 48.47120161])

# %%
y_test_pred = model.predict(X_test)

# %%
train_score = model.score(X_train, y_train)

# %%
test_score = model.score(X_test, y_test)

# %%
# R-squared value
train_score
# Out:
# 0.7548474052763332

# %%
test_score
# Out:
# 0.6752606706162881
