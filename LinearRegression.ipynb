# %%
# Import pandas dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
# Load cleaned byarea_df
c_byarea_df = pd.read_csv('cleaned_byarea_df.txt', ',')
c_byarea_df.head()
# Out:
# C:\Users\yingk\anaconda3\envs\mlenv\lib\site-packages\IPython\core\interactiveshell.py:3457: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only
#   exec(code_obj, self.user_global_ns, self.user_ns)
#       AREA  AGE_ADJUSTED_CI_LOWER  AGE_ADJUSTED_CI_UPPER  AGE_ADJUSTED_RATE  \
# 0  Alabama                  359.7                  374.7              367.2
# 1  Alabama                  160.6                  170.5              165.5
# 2  Alabama                  362.1                  377.1              369.5
# 3  Alabama                  160.8                  170.6              165.7
# 4  Alabama                  377.7                  392.9              385.2
#
#   EVENT_TYPE  POPULATION       RACE     SEX                       SITE  YEAR  \
# 0  Incidence     2293259  All Races  Female  All Cancer Sites Combined  1999
# 1  Mortality     2293259  All Races  Female  All Cancer Sites Combined  1999
# 2  Incidence     2302835  All Races  Female  All Cancer Sites Combined  2000
# 3  Mortality     2302835  All Races  Female  All Cancer Sites Combined  2000
# 4  Incidence     2309496  All Races  Female  All Cancer Sites Combined  2001
#
#    CRUDE_CI_LOWER  CRUDE_CI_UPPER  CRUDE_RATE
# 0           397.3           413.8       405.5
# 1           184.8           196.1       190.4
# 2           403.2           419.8       411.4
# 3           186.5           197.9       192.2
# 4           423.3           440.3       431.7

# %%
# check c_byarea_df columns
c_byarea_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 949308 entries, 0 to 949307
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   AREA                   949308 non-null  object
#  1   AGE_ADJUSTED_CI_LOWER  949308 non-null  float64
#  2   AGE_ADJUSTED_CI_UPPER  949308 non-null  float64
#  3   AGE_ADJUSTED_RATE      949308 non-null  float64
#  4   EVENT_TYPE             949308 non-null  object
#  5   POPULATION             949308 non-null  int64
#  6   RACE                   949308 non-null  object
#  7   SEX                    949308 non-null  object
#  8   SITE                   949308 non-null  object
#  9   YEAR                   949308 non-null  int64
#  10  CRUDE_CI_LOWER         949308 non-null  float64
#  11  CRUDE_CI_UPPER         949308 non-null  float64
#  12  CRUDE_RATE             949308 non-null  float64
# dtypes: float64(6), int64(2), object(5)
# memory usage: 94.2+ MB

# %%
# load per_capita_income file
income_df = pd.read_csv('cleaned_per_capita_income.csv')
income_df
# Out:
#                  GeoName   1999   2000   2001   2002   2003   2004   2005  \
# 0          United States  28693  30672  31617  31839  32717  34280  35868
# 1                Alabama  23333  24306  25057  25648  26673  28434  29949
# 2                 Alaska  29951  32044  33626  34756  35996  37016  39075
# 3                Arizona  24960  26388  27008  27353  28393  30221  32327
# 4               Arkansas  21871  22781  23873  24306  25595  27059  28227
# 5             California  30773  33410  34046  34131  35272  37070  38932
# 6               Colorado  31305  34029  34897  34438  34856  35819  37797
# 7            Connecticut  39700  43070  45153  44697  44997  47238  49738
# 8               Delaware  31181  33884  36922  37658  38065  38974  39370
# 9   District of Columbia  39798  43524  44871  45147  46011  50088  52947
# 10               Florida  27689  29466  30418  30810  31785  33778  35999
# 11               Georgia  27254  28851  29762  30133  30896  32034  33445
# 43  33065  34164  ...  35851  37727  39373  39454  40753  42535  43499  44879
# 44  35630  37085  ...  39034  42037  44241  44816  47370  47465  46586  49231
# 45  31327  33165  ...  32218  34190  36005  36511  38168  40459  41750  43241
# 46  37008  38944  ...  41733  43982  45277  45770  47641  48876  49621  50771
# 47  42385  44248  ...  45513  47608  49309  48573  50318  52238  53268  54879
# 48  40027  42819  ...  42348  44225  47320  47857  50890  53083  54918  57265
# 49  28704  29711  ...  32762  34581  35453  35318  36570  37468  37380  39140
# 50  36338  37816  ...  39175  41209  42944  43050  44709  46548  47205  48758
# 51  44492  46278  ...  46649  50783  54213  53776  57749  57846  54827  57184
#
#      2018   2019
# 0   53786  56250
# 1   41539  43288
# 2   59618  61316
# 3   45466  48124
# 4   43384  44324
# 5   61508  64919
# 6   58453  62124
# 7   72926  75533
# 8   52716  54217
# 9   82708  84671
# 10  51520  54560
# 11  46855  49083
# 12  52164  54700
# 13  43217  45924
# 14  56536  58438
# 15  46945  48749
# 16  49163  50367
# 17  50663  52876
# 18  41974  43875
# 19  46057  47668
# 20  48141  50728
# 21  60577  62313
# 22  69693  73213
# 23  47457  49142
# 24  56539  58543
# 25  37900  39445
# 26  47085  49001
# 27  47612  50289
# 28  51916  54182
# 29  49678  52602
# 30  60831  64747
# 31  64914  68438
# 32  41218  43530
# 33  64849  67366
# 34  46352  48741
# 35  55396  57110
# 36  48327  50035
# 37  46415  48646
# 38  50567  52718
# 39  55030  56952
# 40  52659  55830
# 41  44155  46681
# 42  52166  55294
# 43  46870  49343
# 44  52005  54076
# 45  45665  48580
# 46  52409  55442
# 47  56619  59073
# 48  60221  64189
# 49  41279  42951
# 50  50908  52893
# 51  60472  64117
#
# [52 rows x 22 columns]

# %% [markdown]
# ## prepare INCOME data

# %%
# reshape income_df to long form to merge with cancer data
# how to: https://towardsdatascience.com/how-to-reshape-a-pandas-dataframe-98b42c428a8

# first need to rename each column in order to use the wide_to_long()
income_df.rename(columns={'1999':'INCOME_1999',
                       '2000':'INCOME_2000',
                       '2001':'INCOME_2001',
                       '2002':'INCOME_2002',
                       '2003':'INCOME_2003',
                       '2004':'INCOME_2004',
                       '2005':'INCOME_2005',
                       '2006':'INCOME_2006',
                       '2007':'INCOME_2007',
                       '2008':'INCOME_2008',
                       '2009':'INCOME_2009',
                       '2010':'INCOME_2010',
                       '2011':'INCOME_2011',
                       '2012':'INCOME_2012',
                       '2013':'INCOME_2013',
                       '2014':'INCOME_2014',
                       '2015':'INCOME_2015',
                       '2016':'INCOME_2016',
                       '2017':'INCOME_2017',
                       '2018':'INCOME_2018',
                       '2019':'INCOME_2019',}, inplace=True)

# %%
income_df.head()
# Out:
#          GeoName  INCOME_1999  INCOME_2000  INCOME_2001  INCOME_2002  \
# 0  United States        28693        30672        31617        31839
# 1        Alabama        23333        24306        25057        25648
# 2         Alaska        29951        32044        33626        34756
# 3        Arizona        24960        26388        27008        27353
# 4       Arkansas        21871        22781        23873        24306
#
#    INCOME_2003  INCOME_2004  INCOME_2005  INCOME_2006  INCOME_2007  ...  \
# 0        32717        34280        35868        38120        39883  ...
# 1        26673        28434        29949        31474        32739  ...
# 2        35996        37016        39075        41157        43906  ...
# 3        28393        30221        32327        34703        35872  ...
# 4        25595        27059        28227        29617        31303  ...
#
#    INCOME_2010  INCOME_2011  INCOME_2012  INCOME_2013  INCOME_2014  \
# 0        40683        42747        44548        44798        46887
# 1        33946        35010        35824        36014        37055
# 2        49652        52569        53708        52812        55867
# 3        33876        35321        36545        37139        38756
# 4        32372        34279        36582        36677        38749
#
#    INCOME_2015  INCOME_2016  INCOME_2017  INCOME_2018  INCOME_2019
# 0        48725        49613        51550        53786        56250
# 1        38531        39014        40223        41539        43288
# 2        57575        56278        57189        59618        61316
# 3        40334        41473        43497        45466        48124
# 4        39968        40873        41890        43384        44324
#
# [5 rows x 22 columns]

# %%
# convert income_df to long format
income_long_df = pd.wide_to_long(income_df, 
                              stubnames=['INCOME'],
                              i='GeoName',
                              j='YEAR',
                              sep="_",
                              suffix='\w+')
income_long_df
# Out:
#                     INCOME
# GeoName       YEAR
# United States 1999   28693
# Alabama       1999   23333
# Alaska        1999   29951
# Arizona       1999   24960
# Arkansas      1999   21871
# ...                    ...
# Virginia      2019   59073
# Washington    2019   64189
# West Virginia 2019   42951
# Wisconsin     2019   52893
# Wyoming       2019   64117
#
# [1092 rows x 1 columns]

# %%
# Adding back index for ease of merging later
income_long_df = income_long_df.reset_index()
income_long_df
# Out:
#             GeoName  YEAR  INCOME
# 0     United States  1999   28693
# 1           Alabama  1999   23333
# 2            Alaska  1999   29951
# 3           Arizona  1999   24960
# 4          Arkansas  1999   21871
# ...             ...   ...     ...
# 1087       Virginia  2019   59073
# 1088     Washington  2019   64189
# 1089  West Virginia  2019   42951
# 1090      Wisconsin  2019   52893
# 1091        Wyoming  2019   64117
#
# [1092 rows x 3 columns]

# %% [markdown]
# ## prepare cancer data

# %%
# filter for rows with total state cancer incidence
state_all_df = c_byarea_df.loc[(c_byarea_df['EVENT_TYPE']=='Incidence') &
                              (c_byarea_df['SEX']=='Male and Female') &
                              (c_byarea_df['RACE']=='All Races') &
                              (c_byarea_df['SITE']=='All Cancer Sites Combined') &
                              (c_byarea_df['YEAR']!= 20152019)
                              ]
state_all_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1084 entries, 2002 to 932476
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   AREA                   1084 non-null   object
#  1   AGE_ADJUSTED_CI_LOWER  1084 non-null   float64
#  2   AGE_ADJUSTED_CI_UPPER  1084 non-null   float64
#  3   AGE_ADJUSTED_RATE      1084 non-null   float64
#  4   EVENT_TYPE             1084 non-null   object
#  5   POPULATION             1084 non-null   int64
#  6   RACE                   1084 non-null   object
#  7   SEX                    1084 non-null   object
#  8   SITE                   1084 non-null   object
#  9   YEAR                   1084 non-null   int64
#  10  CRUDE_CI_LOWER         1084 non-null   float64
#  11  CRUDE_CI_UPPER         1084 non-null   float64
#  12  CRUDE_RATE             1084 non-null   float64
# dtypes: float64(6), int64(2), object(5)
# memory usage: 118.6+ KB

# %%
state_all_df.head()
# Out:
#          AREA  AGE_ADJUSTED_CI_LOWER  AGE_ADJUSTED_CI_UPPER  \
# 2002  Alabama                  419.3                  431.3
# 2004  Alabama                  427.1                  439.2
# 2006  Alabama                  448.5                  460.8
# 2008  Alabama                  450.1                  462.4
# 2010  Alabama                  431.7                  443.7
#
#       AGE_ADJUSTED_RATE EVENT_TYPE  POPULATION       RACE              SEX  \
# 2002              425.3  Incidence     4430141  All Races  Male and Female
# 2004              433.1  Incidence     4452173  All Races  Male and Female
# 2006              454.6  Incidence     4467634  All Races  Male and Female
# 2008              456.2  Incidence     4480089  All Races  Male and Female
# 2010              437.7  Incidence     4503491  All Races  Male and Female
#
#                            SITE  YEAR  CRUDE_CI_LOWER  CRUDE_CI_UPPER  \
# 2002  All Cancer Sites Combined  1999           429.4           441.8
# 2004  All Cancer Sites Combined  2000           440.0           452.4
# 2006  All Cancer Sites Combined  2001           465.6           478.4
# 2008  All Cancer Sites Combined  2002           471.8           484.6
# 2010  All Cancer Sites Combined  2003           456.1           468.7
#
#       CRUDE_RATE
# 2002       435.6
# 2004       446.2
# 2006       472.0
# 2008       478.1
# 2010       462.4

# %%
# Pick out just the columns needed for our linear regression analysis
# CRUDE_RATE as the independent variable
state_lr_df = state_all_df[['AREA', 'YEAR', 'CRUDE_RATE']]
state_lr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1084 entries, 2002 to 932476
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   AREA        1084 non-null   object
#  1   YEAR        1084 non-null   int64
#  2   CRUDE_RATE  1084 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 33.9+ KB

# %%
state_lr_df
# Out:
#            AREA  YEAR  CRUDE_RATE
# 2002    Alabama  1999       435.6
# 2004    Alabama  2000       446.2
# 2006    Alabama  2001       472.0
# 2008    Alabama  2002       478.1
# 2010    Alabama  2003       462.4
# ...         ...   ...         ...
# 932466  Wyoming  2015       454.1
# 932470  Wyoming  2016       478.6
# 932472  Wyoming  2017       498.1
# 932474  Wyoming  2018       492.4
# 932476  Wyoming  2019       521.8
#
# [1084 rows x 3 columns]

# %% [markdown]
# ## prepare Linear Regression data

# %%
# merge the cancer df and income df using "State" & "Year"
lr_df = pd.merge(income_long_df, state_lr_df, how='left', left_on=['GeoName', 'YEAR'], right_on=['AREA', 'YEAR'])
lr_df
# Out:
#             GeoName  YEAR  INCOME           AREA  CRUDE_RATE
# 0     United States  1999   28693            NaN         NaN
# 1           Alabama  1999   23333        Alabama       435.6
# 2            Alaska  1999   29951         Alaska       315.0
# 3           Arizona  1999   24960        Arizona       423.9
# 4          Arkansas  1999   21871       Arkansas       473.7
# ...             ...   ...     ...            ...         ...
# 1087       Virginia  2019   59073       Virginia       486.7
# 1088     Washington  2019   64189     Washington       509.2
# 1089  West Virginia  2019   42951  West Virginia       678.9
# 1090      Wisconsin  2019   52893      Wisconsin       605.4
# 1091        Wyoming  2019   64117        Wyoming       521.8
#
# [1092 rows x 5 columns]

# %%
lr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1092 entries, 0 to 1091
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   GeoName     1092 non-null   object
#  1   YEAR        1092 non-null   int64
#  2   INCOME      1092 non-null   int64
#  3   AREA        1063 non-null   object
#  4   CRUDE_RATE  1063 non-null   float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 51.2+ KB

# %%
# check to see what rows are missing data
# looks ok, mostly US-total 
lr_df[lr_df['AREA'].isnull()]
# Out:
#             GeoName  YEAR  INCOME AREA  CRUDE_RATE
# 0     United States  1999   28693  NaN         NaN
# 25      Mississippi  1999   20709  NaN         NaN
# 42     South Dakota  1999   25306  NaN         NaN
# 52    United States  2000   30672  NaN         NaN
# 77      Mississippi  2000   21681  NaN         NaN
# 94     South Dakota  2000   26825  NaN         NaN
# 104   United States  2001   31617  NaN         NaN
# 129     Mississippi  2001   22845  NaN         NaN
# 156   United States  2002   31839  NaN         NaN
# 181     Mississippi  2002   23219  NaN         NaN
# 208   United States  2003   32717  NaN         NaN
# 260   United States  2004   34280  NaN         NaN
# 312   United States  2005   35868  NaN         NaN
# 364   United States  2006   38120  NaN         NaN
# 416   United States  2007   39883  NaN         NaN
# 468   United States  2008   41026  NaN         NaN
# 520   United States  2009   39356  NaN         NaN
# 572   United States  2010   40683  NaN         NaN
# 624   United States  2011   42747  NaN         NaN
# 676   United States  2012   44548  NaN         NaN
# 728   United States  2013   44798  NaN         NaN
# 780   United States  2014   46887  NaN         NaN
# 832   United States  2015   48725  NaN         NaN
# 884   United States  2016   49613  NaN         NaN
# 936   United States  2017   51550  NaN         NaN
# 988   United States  2018   53786  NaN         NaN
# 1017         Nevada  2018   49678  NaN         NaN
# 1040  United States  2019   56250  NaN         NaN
# 1069         Nevada  2019   52602  NaN         NaN

# %%
lr_df = lr_df.dropna()
lr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1063 entries, 1 to 1091
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   GeoName     1063 non-null   object
#  1   YEAR        1063 non-null   int64
#  2   INCOME      1063 non-null   int64
#  3   AREA        1063 non-null   object
#  4   CRUDE_RATE  1063 non-null   float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 49.8+ KB

# %%
# plot of 1063 raw data points
plt.scatter(lr_df.CRUDE_RATE, lr_df.INCOME)
plt.xlabel("CRUDE_RATE")
plt.ylabel("INCOME")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Supervised ML - Linear Regression

# %%
# set up for ML linear regression
X = lr_df.CRUDE_RATE.values.reshape(-1,1)

# %%
X.shape
# Out:
# (1063, 1)

# %%
y = lr_df.INCOME

# %%
model = LinearRegression()

# %%
model.fit(X,y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X)
print(y_pred.shape)
# Out:
# (1063,)

# %%
plt.scatter(X, y)
plt.plot(X, y_pred, color='red')
plt.xlabel("CRUDE_RATE")
plt.ylabel("INCOME")
plt.show()

# %%
print(model.coef_)
print(model.intercept_)
# Out:
# [33.65020591]
# 22984.31729571302

# %%
r2_score(y, y_pred)
# Out:
# 0.0522906963577946
